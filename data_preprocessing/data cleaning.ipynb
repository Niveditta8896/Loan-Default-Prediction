# %%
# important libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # 1. detecting Missing values

# %%
data=pd.read_csv("merged_data.csv")

# %%
data
# Out:
#      Unnamed: 0   loan_id  Gender Married dependents     education  \
# 0             0  LP001002    Male      No          0      Graduate
# 1             1  LP001003    Male     Yes          1      Graduate
# 2             2  LP001005    Male     Yes          0      Graduate
# 3             3  LP001006    Male     Yes          0  Not Graduate
# 4             4  LP001008    Male      No          0      Graduate
# ..          ...       ...     ...     ...        ...           ...
# 609         609  LP002978  Female      No          0      Graduate
# 610         610  LP002979    Male     Yes         3+      Graduate
# 611         611  LP002983    Male     Yes          1      Graduate
# 612         612  LP002984    Male     Yes          2      Graduate
# 613         613  LP002990  Female      No          0      Graduate
#
#     Self_Employed  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0              No           5849.0                0.0         NaN
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'loan_id', 'Gender', 'Married', 'dependents', 'education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
data=data.drop(["loan_id",'Unnamed: 0'],axis=1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Gender             601 non-null    object
#  1   Married            611 non-null    object
#  2   dependents         599 non-null    object
#  3   education          614 non-null    object
#  4   Self_Employed      582 non-null    object
#  5   ApplicantIncome    614 non-null    float64
#  6   CoapplicantIncome  614 non-null    float64
#  7   LoanAmount         592 non-null    float64
#  8   Loan_Amount_Term   600 non-null    float64
#  9   Credit_History     564 non-null    float64
#  10  Property_Area      614 non-null    object
#  11  Loan_Status        614 non-null    object
# dtypes: float64(5), object(7)
# memory usage: 57.7+ KB

# %%
data.isna().sum()
# Out:
# Gender               0
# Married              0
# dependents           0
# education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
data["Gender"].mode()[0]
# Out:
# 'Male'

# %%
data['Gender'].fillna(data['Gender'].mode()[0], inplace=True)

# %%
data['Married'].fillna(data['Married'].mode()[0], inplace=True)

# %%
data['dependents'].fillna(data['dependents'].mode()[0], inplace=True)

# %%
data['Self_Employed'].fillna(data['Self_Employed'].mode()[0], inplace=True)

# %%
data['LoanAmount'].mean()
# Out:
# 146.41216216216216

# %%
data['LoanAmount'].fillna(data['LoanAmount'].mean(), inplace=True)

# %%
data['Loan_Amount_Term'].fillna(data['Loan_Amount_Term'].mean(), inplace=True)

# %%
data['Credit_History'].fillna(data['Credit_History'].mean(), inplace=True)

# %%
data
# Out:
#      Gender Married dependents     education Self_Employed  ApplicantIncome  \
# 0      Male      No          0      Graduate            No           5849.0
# 1      Male     Yes          1      Graduate            No           4583.0
# 2      Male     Yes          0      Graduate           Yes           3000.0
# 3      Male     Yes          0  Not Graduate            No           2583.0
# 4      Male      No          0      Graduate            No           6000.0
# ..      ...     ...        ...           ...           ...              ...
# 609  Female      No          0      Graduate            No           2900.0
# 610    Male     Yes         3+      Graduate            No           4106.0
# 611    Male     Yes          1      Graduate            No           8072.0
# 612    Male     Yes          2      Graduate            No           7583.0
# 613  Female      No          0      Graduate           Yes           4583.0
#
# ...

# %% [markdown]
# # HOW to rename a column

# %%
data.rename(columns={"loan_id":"Loan_ID"},inplace=True)

# %%
data
# Out:
#      Gender Married dependents     education Self_Employed  ApplicantIncome  \
# 0      Male      No          0      Graduate            No           5849.0
# 1      Male     Yes          1      Graduate            No           4583.0
# 2      Male     Yes          0      Graduate           Yes           3000.0
# 3      Male     Yes          0  Not Graduate            No           2583.0
# 4      Male      No          0      Graduate            No           6000.0
# ..      ...     ...        ...           ...           ...              ...
# 609  Female      No          0      Graduate            No           2900.0
# 610    Male     Yes         3+      Graduate            No           4106.0
# 611    Male     Yes          1      Graduate            No           8072.0
# 612    Male     Yes          2      Graduate            No           7583.0
# 613  Female      No          0      Graduate           Yes           4583.0
#
# ...

# %%
data.rename(columns={"dependents":"Dependents"},inplace=True)

# %%
data.rename(columns={"education":"Education"},inplace=True)

# %% [markdown]
# # we r going to rectify inconsistent data

# %%
data["Dependents"]=data["Dependents"].astype("str")

# %%
data["Loan_Status"].replace({"Y\r":"yes","N\r":"no"},inplace=True)

# %%
data["Dependents"]=data["Dependents"].str.replace("+","",regex=False)

# %% [markdown]
# # we r going to split data if required

# %%
# if we hv 2 values combined we can split it 2 2 different cols using str.split or str.extract if regex method is followed

# %% [markdown]
# # lets change data type

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Gender             614 non-null    object
#  1   Married            614 non-null    object
#  2   Dependents         614 non-null    object
#  3   Education          614 non-null    object
#  4   Self_Employed      614 non-null    object
#  5   ApplicantIncome    614 non-null    float64
#  6   CoapplicantIncome  614 non-null    float64
#  7   LoanAmount         614 non-null    float64
#  8   Loan_Amount_Term   614 non-null    float64
#  9   Credit_History     614 non-null    float64
#  10  Property_Area      614 non-null    object
#  11  Loan_Status        614 non-null    object
# dtypes: float64(5), object(7)
# memory usage: 57.7+ KB

# %%
data=data.astype({"Dependents":"int64"})

# %% [markdown]
# # lets merge columns

# %%
data["Gender"]+ " "+data["Married"]
# Out:
# 0        Male No
# 1       Male Yes
# 2       Male Yes
# 3       Male Yes
# 4        Male No
#          ...
# 609    Female No
# 610     Male Yes
# 611     Male Yes
# 612     Male Yes
# 613    Female No
# Length: 614, dtype: object

# %% [markdown]
# # lets identify and delete duplicates

# %%
data[data.duplicated()]# so no duplicates found
# Out:
# Empty DataFrame
# Columns: [Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History, Property_Area, Loan_Status]
# Index: []

# %%
cleaned_data=data

# %%
cleaned_data.to_csv("cleaned_data.csv")

# %%
cleaned_data.isna().sum()
# Out:
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64
